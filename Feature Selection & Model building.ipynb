# %% [markdown]
# #### Feature Selection

# %%
import pandas as pd
import numpy as np

# %%
x_train=pd.read_csv('x_train.csv')
x_test=pd.read_csv('x_test.csv')
y_train=pd.read_csv('y_train.csv')
y_test=pd.read_csv('y_test.csv')
x_train.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  Street     Alley  LotShape  \
# 0    0.000000  0.823555     0.606846  0.465232     1.0  1.000000  0.000000
# 1    0.487992  0.823555     0.520677  0.445178     1.0  1.000000  0.534621
# 2    0.180103  0.823555     0.584767  0.477922     1.0  1.000000  0.000000
# 3    0.407007  0.823555     0.529148  0.420672     1.0  1.000000  0.000000
# 4    0.407007  0.823555     0.437251  0.315267     1.0  0.759554  0.000000
#
#    LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC     Fence  \
# 0     0.414313        1.0   0.000000  ...       0.0     0.0  1.000000
# 1     0.414313        1.0   0.000000  ...       0.0     0.0  1.000000
# 2     0.414313        1.0   0.000000  ...       0.0     0.0  0.249065
# 3     0.414313        1.0   0.067646  ...       0.0     0.0  0.249065
# 4     0.414313        1.0   0.000000  ...       0.0     0.0  1.000000
#
#    MiscFeature  MiscVal    MoSold  SaleType  LotFrontage_missing  \
# ...

# %%
from sklearn.tree import ExtraTreeRegressor
tree_reg=ExtraTreeRegressor()
tree_reg.fit(x_train,y_train)
# Out:
# ExtraTreeRegressor()

# %%
tree_reg.feature_importances_
# Out:
# array([2.78179980e-03, 3.90773904e-03, 1.15983460e-02, 5.22016116e-03,
#        0.00000000e+00, 1.59760781e-04, 2.10151035e-03, 4.75489494e-03,
#        0.00000000e+00, 3.61775350e-03, 3.03123442e-03, 6.73174147e-02,
#        3.89591604e-04, 0.00000000e+00, 4.65585386e-04, 3.84657251e-03,
#        2.84547702e-02, 2.24510801e-03, 3.40567780e-03, 2.00663626e-03,
#        2.75198770e-03, 2.83325551e-04, 9.05914516e-04, 1.48372563e-03,
#        2.65380996e-03, 3.80425400e-01, 7.58234155e-04, 1.67962010e-03,
#        5.52823786e-03, 1.22568232e-04, 9.02902181e-03, 6.68227440e-03,
#        1.92423375e-02, 9.62421890e-04, 3.04564660e-04, 2.86343488e-03,
#        1.87281225e-02, 3.81294085e-05, 1.02300450e-03, 1.08796941e-02,
#        8.09873611e-05, 1.20689227e-02, 2.91574620e-03, 5.46789586e-06,
#        8.20313249e-02, 3.43900289e-03, 7.93258964e-04, 1.05003211e-02,
#        5.20166544e-03, 4.99142438e-03, 1.33498218e-02, 1.11970699e-02,
# ...

# %%
sum(tree_reg.feature_importances_)
# Out:
# 0.9999999999999994

# %%
print(len(tree_reg.feature_importances_))
print([val for val in tree_reg.feature_importances_ if val>0.005])
print(len([val for val in tree_reg.feature_importances_ if val>0.005]))
print(sum([val for val in tree_reg.feature_importances_ if val>0.005]))
# Out:
# 79
# [0.011598345959798218, 0.0052201611645822255, 0.06731741465941042, 0.028454770154370097, 0.38042540027345545, 0.005528237858715832, 0.00902902180932352, 0.006682274395508082, 0.019242337482093152, 0.018728122464548476, 0.010879694100862515, 0.01206892272243542, 0.08203132488293982, 0.0105003210804643, 0.005201665437872497, 0.013349821816429118, 0.011197069887788067, 0.005106021460391553, 0.007052244891165337, 0.023159435704437677, 0.008423422951760075, 0.03399727585116117, 0.13661661106186304]
# 23
# 0.9118099180713759

# %%
selected_cols=x_train.columns[tree_reg.feature_importances_>0.005]
selected_cols
# Out:
# Index(['LotFrontage', 'LotArea', 'Neighborhood', 'OverallQual', 'ExterQual',
#        'BsmtQual', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'TotalBsmtSF',
#        'CentralAir', '1stFlrSF', 'GrLivArea', 'FullBath', 'HalfBath',
#        'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional',
#        'Fireplaces', 'FireplaceQu', 'GarageFinish', 'GarageArea'],
#       dtype='object')

# %%
x_train=x_train[selected_cols]
x_test=x_test[selected_cols]
x_train.head()
# Out:
#    LotFrontage   LotArea  Neighborhood  OverallQual  ExterQual  BsmtQual  \
# 0     0.606846  0.465232      0.211525     0.424283   0.204538  0.161983
# 1     0.520677  0.445178      0.421873     0.575717   0.524415  0.449589
# 2     0.584767  0.477922      0.132647     0.424283   0.204538  0.044751
# 3     0.529148  0.420672      0.196957     0.424283   0.204538  0.449589
# 4     0.437251  0.315267      0.196957     0.424283   0.204538  0.161983
#
#    BsmtExposure  BsmtFinType1  BsmtFinSF1  TotalBsmtSF  ...  FullBath  \
# 0      0.394019      0.320778    0.525827     0.540776  ...  0.333333
# 1      0.394019      0.505495    0.000000     0.328828  ...  0.666667
# 2      0.394019      0.505495    0.000000     0.327594  ...  0.333333
# 3      0.394019      0.434202    0.324507     0.300843  ...  0.333333
# 4      0.394019      0.358462    0.124328     0.422250  ...  0.666667
#
#    HalfBath  KitchenAbvGr  KitchenQual  TotRmsAbvGrd  Functional  Fireplaces  \
# ...

# %% [markdown]
# #### Model Building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
lin_model=LinearRegression()
lin_model.fit(x_train,y_train)
y_pred=lin_model.predict(x_test)
lin_model_r2_score=r2_score(y_test,y_pred)
print('lin_model_r2_score is :',lin_model_r2_score)
# Out:
# lin_model_r2_score is : 0.8779989823791048

# %%
from sklearn.metrics import mean_squared_error,mean_squared_log_error
from math import sqrt
lin_model_rmle_score=sqrt(mean_squared_log_error(y_test,y_pred))
print('lin_model_rmle_score is :',lin_model_rmle_score)
# Out:
# lin_model_rmle_score is : 0.17416735994733165

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV,KFold
folds=KFold(n_splits=5)
model=Ridge(random_state=42)
params={'alpha':[0.0001,0.001,0.005,0.01,0.05,0.1,1,2,4,5],'solver':['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']}
ridge_cv=GridSearchCV(model,param_grid=params,cv=folds)
ridge_cv.fit(x_train,y_train)
y_pred=ridge_cv.predict(x_test)
ridge_model_r2_score=r2_score(y_test,y_pred)
print('ridge_model_r2_score is :',ridge_model_r2_score) 
ridge_model_rmle_score=sqrt(mean_squared_log_error(y_test,y_pred))
print('ridge_model_rmle_score is :',ridge_model_rmle_score)
print(ridge_cv.best_estimator_)
# Out:
# ridge_model_r2_score is : 0.878308943074786
# ridge_model_rmle_score is : 0.1717807181331412
# Ridge(alpha=1, random_state=42, solver='sag')

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV,KFold
folds=KFold(n_splits=5)
model=Lasso(random_state=42)
params={'alpha':[0.0001,0.001,0.005,0.01,0.05,0.1,1,2,4,5]}
lasso_cv=GridSearchCV(model,param_grid=params,cv=folds)
lasso_cv.fit(x_train,y_train)
y_pred=lasso_cv.predict(x_test)
lasso_model_r2_score=r2_score(y_test,y_pred)
print('lasso_model_r2_score is :',lasso_model_r2_score) 
lasso_model_rmle_score=sqrt(mean_squared_log_error(y_test,y_pred))
print('lasso_model_rmle_score is :',lasso_model_rmle_score)
print(lasso_cv.best_estimator_)
# Out:
# lasso_model_r2_score is : 0.877998983776644
# lasso_model_rmle_score is : 0.17416735508617384
# Lasso(alpha=0.0001, random_state=42)

# %%
from sklearn.neighbors import KNeighborsRegressor
folds=KFold(n_splits=5)
model=KNeighborsRegressor(n_jobs=-1)
params={'n_neighbors':[3,5,6,7,9,10],'weights':['uniform','distance'],'p':[0.5,1,1.5,2]}
knn_cv=GridSearchCV(model,param_grid=params,cv=folds)
knn_cv.fit(x_train,y_train)
y_pred=knn_cv.predict(x_test)
knn_model_r2_score=r2_score(y_test,y_pred)
print('knn_model_r2_score is :',knn_model_r2_score) 
knn_model_rmle_score=sqrt(mean_squared_log_error(y_test,y_pred))
print('knn_model_rmle_score is :',knn_model_rmle_score)
print(knn_cv.best_estimator_)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\admin\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 1110, in fit
#     return self._fit(X)
#   File "C:\Users\admin\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 350, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\admin\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 347, in _check_algorithm_metric
#     raise ValueError("p must be greater than one for minkowski metric")
# ValueError: p must be greater than one for minkowski metric
#
#   FitFailedWarning)
# ...

# %%
from sklearn.svm import SVR
folds=KFold(n_splits=5)
model=SVR()
params={'kernel':['poly','rbf'],'degree':[2,3],'C':np.arange(0,1100,100)}
svr_cv=GridSearchCV(model,param_grid=params,cv=folds)
svr_cv.fit(x_train,y_train)
y_pred=svr_cv.predict(x_test)
svr_model_r2_score=r2_score(y_test,y_pred)
print('svr_model_r2_score is :',svr_model_r2_score) 
svr_model_rmle_score=sqrt(mean_squared_log_error(y_test,y_pred))
print('svr_model_rmle_score is :',svr_model_rmle_score)
print(svr_cv.best_estimator_)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\admin\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 217, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\admin\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 276, in _dense_fit
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
folds=KFold(n_splits=5)
model=DecisionTreeRegressor()
params={'criterion':['mse','friedman_mse'],'max_depth':[5,6,7,8,9,10],'min_samples_split':np.arange(5,20,3),'min_samples_leaf':np.arange(5,20,3)}
tree_cv=GridSearchCV(model,param_grid=params,cv=folds)
tree_cv.fit(x_train,y_train)
y_pred=tree_cv.predict(x_test)
tree_model_r2_score=r2_score(y_test,y_pred)
print('tree_model_r2_score is :',tree_model_r2_score) 
tree_model_rmle_score=sqrt(mean_squared_log_error(y_test,y_pred))
print('tree_model_rmle_score is :',tree_model_rmle_score)
print(tree_cv.best_estimator_)
# Out:
# tree_model_r2_score is : 0.8529857943293208
# tree_model_rmle_score is : 0.17330123597532568
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=8, min_samples_split=17)

# %%
from sklearn.ensemble import RandomForestRegressor
folds=KFold(n_splits=5)
model=RandomForestRegressor(random_state=42)
params={'max_features':['auto','sqrt','log2'],'min_samples_split':np.arange(5,20,3),'min_samples_leaf':np.arange(5,20,3)}
rf_cv=GridSearchCV(model,param_grid=params,cv=folds)
rf_cv.fit(x_train,y_train)
y_pred=rf_cv.predict(x_test)
rf_model_r2_score=r2_score(y_test,y_pred)
print('rf_model_r2_score is :',rf_model_r2_score) 
rf_model_rmle_score=sqrt(mean_squared_log_error(y_test,y_pred))
print('rf_model_rmle_score is :',rf_model_rmle_score)
print(rf_cv.best_estimator_)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
from sklearn.ensemble import AdaBoostRegressor
folds=KFold(n_splits=5)
#tree=DecisionTreeRegressor(max_depth=5)
model=AdaBoostRegressor(base_estimator=tree, random_state=42)
params={'learning_rate':[0.5,1,2,3],'loss':['linear','square','exponential'],'n_estimators':[50,75,100],'base_estimator':[DecisionTreeRegressor(max_depth=3),DecisionTreeRegressor(max_depth=5),DecisionTreeRegressor()]}
ada_cv=GridSearchCV(model,param_grid=params,cv=folds)
ada_cv.fit(x_train,y_train)
y_pred=ada_cv.predict(x_test)
ada_model_r2_score=r2_score(y_test,y_pred)
print('ada_model_r2_score is :',ada_model_r2_score) 
ada_model_rmle_score=sqrt(mean_squared_log_error(y_test,y_pred))
print('ada_model_rmle_score is :',ada_model_rmle_score)
print(ada_cv.best_estimator_)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
from sklearn.ensemble import GradientBoostingRegressor
folds=KFold(n_splits=5)
model=GradientBoostingRegressor(random_state=42)
params={'learning_rate':[0.01,0.1,0.2],'subsample':[0.85,0.75],'max_depth':[3,5,7] ,'max_features':['auto','sqrt','log2'],'min_samples_split':np.arange(5,20,3),'min_samples_leaf':np.arange(5,20,3)}
skgbr_cv=GridSearchCV(model,param_grid=params,cv=folds)
skgbr_cv.fit(x_train,y_train)
y_pred=skgbr_cv.predict(x_test)
skgbr_model_r2_score=r2_score(y_test,y_pred)
print('skgbr_model_r2_score is :',skgbr_model_r2_score) 
skgbr_model_rmle_score=sqrt(mean_squared_log_error(y_test,y_pred))
print('skgbr_model_rmle_score is :',skgbr_model_rmle_score)
print(skgbr_cv.best_estimator_)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %% [markdown]
# SVR Performed better out of all the models with least root mean square log error

# %%
import pickle
file_name='svr_cv.pkl'
pickle.dump(svr_cv,open(file_name,'wb'))
saved_model=pickle.load(open(file_name,'rb'))
print(saved_model)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=SVR(),
#              param_grid={'C': array([   0,  100,  200,  300,  400,  500,  600,  700,  800,  900, 1000]),
#                          'degree': [2, 3], 'kernel': ['poly', 'rbf']})

# %%
file_name='final_cols.pkl'
pickle.dump(selected_cols,open(file_name,'wb'))
col_list=pickle.load(open(file_name,'rb'))
print(col_list)
# Out:
# Index(['LotFrontage', 'LotArea', 'Neighborhood', 'OverallQual', 'ExterQual',
#        'BsmtQual', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'TotalBsmtSF',
#        'CentralAir', '1stFlrSF', 'GrLivArea', 'FullBath', 'HalfBath',
#        'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional',
#        'Fireplaces', 'FireplaceQu', 'GarageFinish', 'GarageArea'],
#       dtype='object')
